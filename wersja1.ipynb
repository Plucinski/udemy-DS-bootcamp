# %% [markdown]
# <a href="https://colab.research.google.com/github/Plucinski/udemy-DS-bootcamp/blob/main/wersja1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Word!")
# Out:
# Hello Word!

# %%
import numpy as np

# %%
x = np.array([1, 2])
x
print(x)
# Out:
# [1 2]
